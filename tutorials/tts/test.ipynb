# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# !head -n2 hifigan_train_ft.json|jq .
# Out:
# {
#   "audio_filepath": "audio/presentpictureofnsw_02_mann_0532.wav",
#   "text": "not to stop more than ten minutes by the way",
#   "duration": 2.6,
#   "text_no_preprocessing": "not to stop more than ten minutes by the way,",
#   "text_normalized": "not to stop more than ten minutes by the way,",
#   "mel_filepath": "6097_manifest_train_dur_5_mins_local_mels/mel_0.npy"
# }
# {
#   "audio_filepath": "audio/roots_19_morris_0269.wav",
#   "text": "they were men having no country to go back to",
#   "duration": 2.68,
#   "text_no_preprocessing": "they were men having no country to go back to,",
#   "text_normalized": "they were men having no country to go back to,",
#   "mel_filepath": "6097_manifest_train_dur_5_mins_local_mels/mel_1.npy"
# }

# %%
# !head -n2 /home/syl20/data/en/6097_5_mins/6097_manifest_train_dur_5_mins_local_hifigan.json|jq .
# Out:
# {
#   "audio_filepath": "audio/presentpictureofnsw_02_mann_0532.wav",
#   "text": "not to stop more than ten minutes by the way",
#   "duration": 2.6,
#   "text_no_preprocessing": "not to stop more than ten minutes by the way,",
#   "text_normalized": "not to stop more than ten minutes by the way,",
#   "mel_filepath": "/tmp/mels/mel_0.npy"
# }
# {
#   "audio_filepath": "audio/roots_19_morris_0269.wav",
#   "text": "they were men having no country to go back to",
#   "duration": 2.68,
#   "text_no_preprocessing": "they were men having no country to go back to,",
#   "text_normalized": "they were men having no country to go back to,",
#   "mel_filepath": "/tmp/mels/mel_1.npy"
# }

# %%
mel = np.load('6097_manifest_train_dur_5_mins_local_mels.bu/mel_1.npy')
plt.imshow(mel, origin='lower', aspect='auto')

# %%
mel = np.load('6097_manifest_train_dur_5_mins_local_mels/mel_1.npy')
plt.imshow(mel, origin='lower', aspect='auto')

# %%
mel = np.load('/tmp/mels/mel_1.npy')
plt.imshow(mel, origin='lower', aspect='auto')

# %%
mel = np.load('/home/syl20/data/en/6097_5_mins/sup_data/mels/mel_1.npy')
plt.imshow(mel, origin='lower', aspect='auto')
